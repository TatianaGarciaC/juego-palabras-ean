# %% [markdown]
# # Proyecto:
#   * Juego de palabras
# ## Creadores:
#   * Alejandro Asor Corrales Gomez
#   * Anngi Tatiana Garcia Contreras
#   * Ronald Bonilla Alvarez
#   * Luis Guillermo Gutierrez Garzon
# ## Modo de inicio:
#   * El usuario ingresa el nombre de jugador
#     nombre = str(input("Nombre de jugador: "))
#   * El usuario selecciona una opción:
#     * Nivel fácil (Cosas de 4 letras español)
#       if opcion == "1":
#         palabraIngresada = ""
#         #Abrir el archivo base de datos del nivel 1
#         f = open("nivel1.txt", "r")
#         lista = f.readlines()
#         f.close()
#         palabraSecreta = random.choice(lista)
#     * Nivel medio (Comidas de 5 letras español)
#       elif opcion == "2":
#         palabraIngresada = ""
#         #Abrir el archivo base de datos del nivel 2
#         f = open("nivel2.txt", "r")
#         lista = f.readlines()
#         f.close()
#       palabraSecreta = random.choice(lista)
#     * Nivel difícil (Animales de 6 letras español)
#       elif opcion == "3":
#         palabraIngresada = ""
#         #Abrir el archivo base de datos del nivel 3
#         f = open("nivel3.txt", "r")
#         lista = f.readlines()
#         f.close()
#       palabraSecreta = random.choice(lista)
#     * Nivel experto (Tecnología de 7 letras terminos técnicos español e inglés)
#       elif opcion == "4":
#         palabraIngresada = ""
#         #Abrir el archivo base de datos del nivel 4
#         f = open("nivel4.txt", "r")
#         lista = f.readlines()
#         f.close()
#         palabraSecreta = random.choice(lista)
#     * Ver puntajes históricos
#       elif opcion == "5":
#       puntajes.verPuntajes()
#   * El usuario ingreso una opción de nivel
#
#     #Invocar validarPalabra usa el metodo de ue recorre las letras de la palabra ingresada
#     validarPalabra.recorrerPalabra(nombre,palabraIngresada,palabraSecreta,lista)
#
#     #Bucle mientras el usuario no adivine la palabra o se quede sin vidas
#     while palabraIngresada != palabraSecreta:
#
#       * Ingresa la palabra
#
#         #Declaracion de variables palabra ingresada y secreta
#         palabraIngresada = str(input(" Ingrese la palabra: "))
#
#           * El sistema le da pistas
#             #Contador de vidas
#             print(f"\u001b[32m Vidas restantes: {vidas} \033[0;0m ")
#             #Recorrer las letras de la palabra secreta
#             for i in range(len(palabraSecreta)):
#                #Si la letra está en la posición y es la letra correcta
#                 if palabraIngresada[i] == palabraSecreta[i]:
#                    print(f"\033[1;42m {palabraIngresada[i].upper()} \033[0;0m", end="")
#                    aciertos+=2
#                #Si la letra está en la palabra pero no en la posición correcta
#                 elif palabraIngresada[i] in palabraSecreta:
#                     print(f"\u001b[44;1m {palabraIngresada[i].upper()} \033[0;0m", end="")
#                     aciertos+=1
#                 #La letra no está en la palabra
#                 else:
#                     print(f"\033[1;40m {palabraIngresada[i].upper()} \033[0;0m", end="")
#
#         * Guarda el puntaje del usuario
#
#             #Se invoca la lbreria de puntajes
#             #Se usa el metodo de adicionar putaje
#             puntajes.adicionarPuntaje(nombre,aciertos,palabraAdivinada,tiempoJuego,palabraSecreta,vidas)
#               * #Se hace el calculo del puntaje
#                 puntos*aciertos-tiempoJuego
#               * #Guardar el nuevo puntaje en la base de datos de los puntajes
#                   file = open("puntajes.txt", 'a')
#                   file.write((str(puntaje)) + "\t\t" + (nombre) + "\n")
#   * El usuario selecciona ver puntajes historicos
#       #Se invoca la lbreria de puntajes
#       * Muestra los 10 mejores puntajes
#         #Abrir el archivo base de datos de los puntajes
#         file = open("puntajes.txt", 'r')
#
#         #Traer la lista de puntajes
#         lista = file.readlines()
#         lista = [i.split() for i in lista]
#         lista = [i for i in lista if i != []]
#
#         #Ordena la lista de forma ascendente por defecto
#         lista.sort(key=lambda x: int(x[0]), reverse=True)
#         #Primeros 10 puntajes
#         result = lista[:10]
# ### Uso de librerias
#   * Base de datos con archivos .txt para el nivel 1,2,3,4 y los puntajes históricos >>> Se encuentran en el repositorio
#   * import random >>> Este módulo implementa generadores pseudoaleatorios para escoger una palabra de los niveles .txt
#   * puntajes >>> Es una clase encargada de mostrar los puntajes y adicionarlos a la opción de puntajes históricos
#   * validarPalabra >>> Es una clase encargada de recorrer las letras de la palabra ingresada por el usuario
#     y muestra la cercania de las letras con la palabra secreta
